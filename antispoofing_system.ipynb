# %% [markdown]
# <h1>Getting datasets from google drive to workspace </h1>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp -r "/content/gdrive/MyDrive/final_antispoofing.zip" "/content"

# %%
import zipfile
archive = zipfile.ZipFile('/content/final_antispoofing.zip')
archive.extractall('/content')

# %% [markdown]
# <h1>Data Preprocessing </h1>

# %% [markdown]
# <h2> Four Steps </h2>
# <h3>Step 1: Create new directory structure for the datasets</h3>
# <h3>Step 2: Copying images into new directory structure </h3>
# <h3>Step 3: Dataset Exploration </h3>
# <h4> Step 4: Dataset Visualization </h3>

# %% [markdown]
# <h3>Step 1 </h1>

# %% [markdown]
# <h2>Original VS New Directory Structure</h2>

# %%
# from IPython import display
# print("Original Vs New Dataset Structure")
# display.Image('original vs new_dataset.png')

# %%
dataset_dir = '/content/final_antispoofing'
train_dataset_dir = '/content/final_antispoofing/train'
test_dataset_dir = '/content/final_antispoofing/test'

# %%
import os
os.mkdir('/content/antispoofing_dataset')
os.mkdir('/content/antispoofing_dataset/train')
os.mkdir('/content/antispoofing_dataset/test')
os.mkdir('/content/antispoofing_dataset/train/real')
os.mkdir('/content/antispoofing_dataset/train/spoof')
os.mkdir('/content/antispoofing_dataset/test/real')
os.mkdir('/content/antispoofing_dataset/test/spoof')

# %%
train_dir='/content/antispoofing_dataset/train'
test_dir = '/content/antispoofing_dataset/test'

# %% [markdown]
# <h3>Step 2 </h3>

# %%
import shutil
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
def train_test_splits(data_directory):
  for split_type in os.listdir(data_directory):
    path_to_split_type = os.path.join(data_directory,split_type)
    for category in os.listdir(path_to_split_type):
      path_to_category = os.path.join(path_to_split_type,category)
      for subject in os.listdir(path_to_category):
        path_to_subject = os.path.join(path_to_category,subject)
        for img in os.listdir(path_to_subject):
          if split_type == 'train':
            shutil.copy(os.path.join(path_to_subject,img),os.path.join(train_dir,category,img))
          else:
            shutil.copy(os.path.join(path_to_subject,img),os.path.join(test_dir,category,img))

# %%
train_test_splits(data_directory=dataset_dir)

# %% [markdown]
# <h3>Step 3 </h3>

# %% [markdown]
# <h3>Dataset Exploration </h3>

# %%
categories = ['real','spoof']

# %%
print("---------------------Exploring Training Datasets--------------------")
for category in categories:
  path = os.path.join(train_dir,category)
  if category == 'real':
    r1 = len(os.listdir(path))
  else:
    s1 = len(os.listdir(path))
  print("There are {} images in {} directory".format(len(os.listdir(path)),category))
print("There are {} total images in training directory".format(r1+s1))

print("-----------------------Exploring Testing Datasets-------------------------")
for category in categories:
  path = os.path.join(test_dir,category)
  if category == 'real':
    r2 = len(os.listdir(path))
  else:
    s2 = len(os.listdir(path))
  print("There are {} images in {} directory".format(len(os.listdir(path)),category))
print("There are {} total images in testing directory".format(r2+s2))
# Out:
# ---------------------Exploring Training Datasets--------------------
# There are 2102 images in real directory
# There are 2118 images in spoof directory
# There are 4220 total images in training directory
# -----------------------Exploring Testing Datasets-------------------------
# There are 477 images in real directory
# There are 474 images in spoof directory
# There are 951 total images in testing directory

# %% [markdown]
# <h3>Step 4 : Dataset Visualization </h3>

# %%
def get_images(data_dir,number_of_samples):
  image_path = []
  for category in categories:
    path = os.path.join(data_dir,category)
    i = 1
    for img in os.listdir(path):
      if i > number_of_samples:
        break
      else:
        image_path.append(os.path.join(path,img))
        i += 1
  return image_path

# %%
def visualize_dataset(image_path,rows,cols):
  fig = plt.figure(figsize=(20,20))
  for i in range(1,rows * cols + 1):
    fig.add_subplot(rows,cols,i)
    img_array = cv2.imread(image_path[i-1])
    fig.subplots_adjust(hspace=1)
    plt.imshow(cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB))
    plt.xlabel(image_path[i-1].split('/')[-2])
  plt.show()

# %%
training_image_path = get_images(data_dir= train_dir,number_of_samples=25)
print(training_image_path)
print(len(training_image_path))
# Out:
# ['/content/antispoofing_dataset/train/real/Sunil Koirala8.jpg', '/content/antispoofing_dataset/train/real/cxvffhgduyguj30.jpg', '/content/antispoofing_dataset/train/real/WIN_20201110_10_08_19_Pro.jpg', '/content/antispoofing_dataset/train/real/received_811777526056553hr_flip.jpg', '/content/antispoofing_dataset/train/real/Suraj Khanal50.jpg', '/content/antispoofing_dataset/train/real/Sudeep Subedi20brightness0.64.jpg', '/content/antispoofing_dataset/train/real/Rijan Ale18.jpg', '/content/antispoofing_dataset/train/real/Sudeep Subedi6hr_flip.jpg', '/content/antispoofing_dataset/train/real/kjdfjsdkfj50.jpg', '/content/antispoofing_dataset/train/real/received_2809587675925237hr_flip.jpg', '/content/antispoofing_dataset/train/real/received_1865016023636512hr_flip.jpg', '/content/antispoofing_dataset/train/real/WIN_20201110_13_21_17_Pro.jpg', '/content/antispoofing_dataset/train/real/Suraj Khanal46hr_flip.jpg', '/content/antispoofing_dataset/train/real/kjdfjsdkfj40.jpg', '/content/antispoofing_dataset/train/real/20201110_113537.jpg', '/content/antispoofing_dataset/train/real/Sunil Koirala25.jpg', '/content/antispoofing_dataset/train/real/20201110_144916hr_flip.jpg', '/content/antispoofing_dataset/train/real/Prabhat Ale46.jpg', '/content/antispoofing_dataset/train/real/jkhjhj10.jpg', '/content/antispoofing_dataset/train/real/Sumit tamang26.jpg', '/content/antispoofing_dataset/train/real/ghjknhgj40.jpg', '/content/antispoofing_dataset/train/real/Shikshya Gautam38hr_flipbrightness1.22.jpg', '/content/antispoofing_dataset/train/real/Rijan Ale25.jpg', '/content/antispoofing_dataset/train/real/jfdhfjhsdjf33.jpg', '/content/antispoofing_dataset/train/real/Salina Xetri4.jpg', '/content/antispoofing_dataset/train/spoof/sulav218.jpg', '/content/antispoofing_dataset/train/spoof/salina201.jpg', '/content/antispoofing_dataset/train/spoof/samip229.jpg', '/content/antispoofing_dataset/train/spoof/sulav164.jpg', '/content/antispoofing_dataset/train/spoof/samip84.jpg', '/content/antispoofing_dataset/train/spoof/saurav139.jpg', '/content/antispoofing_dataset/train/spoof/samip197.jpg', '/content/antispoofing_dataset/train/spoof/sandy127.jpg', '/content/antispoofing_dataset/train/spoof/samir177.jpg', '/content/antispoofing_dataset/train/spoof/abhi217.jpg', '/content/antispoofing_dataset/train/spoof/rihan210.jpg', '/content/antispoofing_dataset/train/spoof/sulav13.jpg', '/content/antispoofing_dataset/train/spoof/abhi335.jpg', '/content/antispoofing_dataset/train/spoof/abhi96.jpg', '/content/antispoofing_dataset/train/spoof/shikshya122.jpg', '/content/antispoofing_dataset/train/spoof/rihan180.jpg', '/content/antispoofing_dataset/train/spoof/saurav330.jpg', '/content/antispoofing_dataset/train/spoof/saurav326.jpg', '/content/antispoofing_dataset/train/spoof/shikshya171.jpg', '/content/antispoofing_dataset/train/spoof/saurav168.jpg', '/content/antispoofing_dataset/train/spoof/sumit21.jpg', '/content/antispoofing_dataset/train/spoof/saurav143.jpg', '/content/antispoofing_dataset/train/spoof/shikshya40.jpg', '/content/antispoofing_dataset/train/spoof/samir98.jpg', '/content/antispoofing_dataset/train/spoof/samip31.jpg']
# 50

# %% [markdown]
# <h3>Training Dataset Visualization</h3>

# %%
visualize_dataset(image_path=training_image_path,rows=5,cols=10)

# %% [markdown]
# Testing Dataset Visualization

# %%
testing_image_path = get_images(data_dir= test_dir,number_of_samples=25)
print(testing_image_path)
print(len(testing_image_path))
# Out:
# ['/content/antispoofing_dataset/test/real/dddd16.jpg', '/content/antispoofing_dataset/test/real/fjdkjk23.jpg', '/content/antispoofing_dataset/test/real/Shikshya Gautam8brightness1.32.jpg', '/content/antispoofing_dataset/test/real/ghfdtrdtfyh34.jpg', '/content/antispoofing_dataset/test/real/WIN_20201119_10_48_58_Pro.jpg', '/content/antispoofing_dataset/test/real/jfdhfjhsdjf21.jpg', '/content/antispoofing_dataset/test/real/samir ale gurung16.jpg', '/content/antispoofing_dataset/test/real/Shikshya Gautam28hr_flipbrightness1.21.jpg', '/content/antispoofing_dataset/test/real/WIN_20201110_10_06_23_Prohr_flip.jpg', '/content/antispoofing_dataset/test/real/Suraj Khanal38brightness1.23.jpg', '/content/antispoofing_dataset/test/real/Sunil Koirala13brightness0.79.jpg', '/content/antispoofing_dataset/test/real/20201110_144704.jpg', '/content/antispoofing_dataset/test/real/Prabhat Ale24.jpg', '/content/antispoofing_dataset/test/real/Sunil Koirala38hr_flipbrightness0.55.jpg', '/content/antispoofing_dataset/test/real/Shikshya Gautam35brightness1.37.jpg', '/content/antispoofing_dataset/test/real/20201110_113524.jpg', '/content/antispoofing_dataset/test/real/Sunil Koirala22hr_flip.jpg', '/content/antispoofing_dataset/test/real/samir ale gurung21.jpg', '/content/antispoofing_dataset/test/real/Shikshya Gautam33hr_flip.jpg', '/content/antispoofing_dataset/test/real/Samir tamang29.jpg', '/content/antispoofing_dataset/test/real/20201110_113518.jpg', '/content/antispoofing_dataset/test/real/Sumit tamang47.jpg', '/content/antispoofing_dataset/test/real/Shikshya Gautam23brightness1.12.jpg', '/content/antispoofing_dataset/test/real/Sunil Koirala21hr_flip.jpg', '/content/antispoofing_dataset/test/real/Sudeep Subedi24brightness0.66.jpg', '/content/antispoofing_dataset/test/spoof/bishal105.jpg', '/content/antispoofing_dataset/test/spoof/abhi144.jpg', '/content/antispoofing_dataset/test/spoof/bishal201.jpg', '/content/antispoofing_dataset/test/spoof/bishal170.jpg', '/content/antispoofing_dataset/test/spoof/bishal124.jpg', '/content/antispoofing_dataset/test/spoof/shikshya131.jpg', '/content/antispoofing_dataset/test/spoof/samir117.jpg', '/content/antispoofing_dataset/test/spoof/salina215.jpg', '/content/antispoofing_dataset/test/spoof/abhi110.jpg', '/content/antispoofing_dataset/test/spoof/samip306.jpg', '/content/antispoofing_dataset/test/spoof/samir111.jpg', '/content/antispoofing_dataset/test/spoof/samip209.jpg', '/content/antispoofing_dataset/test/spoof/shikshya114.jpg', '/content/antispoofing_dataset/test/spoof/shikshya223.jpg', '/content/antispoofing_dataset/test/spoof/sumit173.jpg', '/content/antispoofing_dataset/test/spoof/bishal39.jpg', '/content/antispoofing_dataset/test/spoof/saurav45.jpg', '/content/antispoofing_dataset/test/spoof/bishal86.jpg', '/content/antispoofing_dataset/test/spoof/sulav132.jpg', '/content/antispoofing_dataset/test/spoof/sulav59.jpg', '/content/antispoofing_dataset/test/spoof/rihan72.jpg', '/content/antispoofing_dataset/test/spoof/samir68.jpg', '/content/antispoofing_dataset/test/spoof/samir31.jpg', '/content/antispoofing_dataset/test/spoof/abhi340.jpg', '/content/antispoofing_dataset/test/spoof/shikshya68.jpg']
# 50

# %%
visualize_dataset(image_path=testing_image_path,rows=5,cols=10)

# %% [markdown]
# **<h3>Model Preparation</h3>**

# %% [markdown]
# <h3>Steps In Model Preparation</h3>
# <h4>1. Choosing Framework and importing necessary libraries </h2>
# <h4> 2. Load datasets and Perform image augmentations </h2>
# <h4> 3. Model Selection  </h3>
# <h4> 4. Compiling our model </h4>
# <h4> 5. Setting our model checkpoints </h4>

# %% [markdown]
# <h4>Step 1 Keras Framework </h1>

# %%
from keras.layers import Dense,Dropout,Input,Flatten
from keras.models import Model
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.models import model_from_json
import json

# %% [markdown]
# <h4>Step 2 </h4>

# %%
train_datagen = ImageDataGenerator(brightness_range=(0.8,1.2),rotation_range=30,width_shift_range=0.2,height_shift_range=0.2,fill_mode='nearest',shear_range=0.2,zoom_range=0.3,rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,target_size=(160,160),color_mode='rgb',
                                                    class_mode='binary',batch_size=25,shuffle=True)
# Out:
# Found 4220 images belonging to 2 classes.

# %%
valid_generator = valid_datagen.flow_from_directory(test_dir,target_size=(160,160),color_mode='rgb',
                                                    class_mode='binary',batch_size=25)
# Out:
# Found 951 images belonging to 2 classes.

# %% [markdown]
# <h4>Step 3 Model Selection and Transfer Learning</h4>

# %%
mobilenet = MobileNetV2(weights="imagenet",include_top=False,input_tensor=Input(shape=(160,160,3)))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
mobilenet.trainable = False

# %%
output = Flatten()(mobilenet.output)
output = Dropout(0.3)(output)
output = Dense(units = 8,activation='relu')(output)
prediction = Dense(1,activation='sigmoid')(output)

# %%
model = Model(inputs = mobilenet.input,outputs = prediction)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 80, 80, 32)   864         ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 80, 80, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 80, 80, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 80, 80, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 80, 80, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 80, 80, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 80, 80, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 80, 80, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 80, 80, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 80, 80, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 80, 80, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 81, 81, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 40, 40, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 40, 40, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 40, 40, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 40, 40, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 40, 40, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 40, 40, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 40, 40, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 40, 40, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 40, 40, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 40, 40, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 40, 40, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 40, 40, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 40, 40, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 40, 40, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 40, 40, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 40, 40, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 40, 40, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 41, 41, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 20, 20, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 20, 20, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 20, 20, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 20, 20, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 20, 20, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 20, 20, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 20, 20, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 20, 20, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 20, 20, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 20, 20, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 20, 20, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 20, 20, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 20, 20, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 20, 20, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 20, 20, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 20, 20, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 20, 20, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 20, 20, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 20, 20, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 20, 20, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 20, 20, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 20, 20, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 20, 20, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 20, 20, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 20, 20, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 20, 20, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 21, 21, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 10, 10, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 10, 10, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 10, 10, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 10, 10, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 10, 10, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 10, 10, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 10, 10, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 10, 10, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 10, 10, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 10, 10, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 10, 10, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 10, 10, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 10, 10, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 10, 10, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 10, 10, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 10, 10, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 10, 10, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 10, 10, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 10, 10, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 10, 10, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 10, 10, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 10, 10, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 10, 10, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 10, 10, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 10, 10, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 10, 10, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 10, 10, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 10, 10, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 10, 10, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 10, 10, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 10, 10, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 10, 10, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 10, 10, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 10, 10, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 10, 10, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 10, 10, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 10, 10, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 10, 10, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 10, 10, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 10, 10, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 10, 10, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 10, 10, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 10, 10, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 10, 10, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 10, 10, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 10, 10, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 10, 10, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 10, 10, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 10, 10, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 10, 10, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 10, 10, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 10, 10, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 10, 10, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 10, 10, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 10, 10, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 10, 10, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 10, 10, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 11, 11, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 5, 5, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 5, 5, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 5, 5, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 5, 5, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 5, 5, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 5, 5, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 5, 5, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 5, 5, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 5, 5, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 5, 5, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 5, 5, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 5, 5, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 5, 5, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 5, 5, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 5, 5, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 5, 5, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 5, 5, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 5, 5, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 5, 5, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 5, 5, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 5, 5, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 5, 5, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 5, 5, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 5, 5, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 5, 5, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 5, 5, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 5, 5, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 5, 5, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 5, 5, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 5, 5, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 5, 5, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 5, 5, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 5, 5, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 5, 5, 1280)   0           ['Conv_1_bn[0][0]']
#
#  flatten (Flatten)              (None, 32000)        0           ['out_relu[0][0]']
#
#  dropout (Dropout)              (None, 32000)        0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 8)            256008      ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 1)            9           ['dense[0][0]']
#
# ==================================================================================================
# Total params: 2,514,001
# Trainable params: 256,017
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %% [markdown]
# <h4>Step 4 Compiling the models </h4>

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='binary_crossentropy',
  optimizer=Adam(
    learning_rate=0.000001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07
),
  metrics=['accuracy']
)

# %% [markdown]
# <h4>Step 5 Setting our model checkpoints </h4>

# %%
import os
os.mkdir('/content/model_weights/')

# %%
model_checkpoint = ModelCheckpoint('./model_weights/finalyearproject_antispoofing_model_{epoch:02d}-{val_accuracy:.6f}.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True,save_weights_only=True)

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // 25,
    validation_data = valid_generator, 
    validation_steps = valid_generator.samples // 25,
    epochs = 100,
    callbacks=[model_checkpoint])
# Out:
# <ipython-input-36-61fac8fe248f>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/100
# 168/168 [==============================] - ETA: 0s - loss: 1.2892 - accuracy: 0.5468
# Epoch 1: val_loss improved from inf to 1.00303, saving model to ./model_weights/finalyearproject_antispoofing_model_01-0.535789.h5
# 168/168 [==============================] - 46s 215ms/step - loss: 1.2892 - accuracy: 0.5468 - val_loss: 1.0030 - val_accuracy: 0.5358
# Epoch 2/100
# 168/168 [==============================] - ETA: 0s - loss: 0.9414 - accuracy: 0.5652
# Epoch 2: val_loss improved from 1.00303 to 0.79953, saving model to ./model_weights/finalyearproject_antispoofing_model_02-0.593684.h5
# 168/168 [==============================] - 36s 215ms/step - loss: 0.9414 - accuracy: 0.5652 - val_loss: 0.7995 - val_accuracy: 0.5937
# Epoch 3/100
# 168/168 [==============================] - ETA: 0s - loss: 0.8227 - accuracy: 0.6005
# Epoch 3: val_loss improved from 0.79953 to 0.68607, saving model to ./model_weights/finalyearproject_antispoofing_model_03-0.640000.h5
# 168/168 [==============================] - 37s 215ms/step - loss: 0.8227 - accuracy: 0.6005 - val_loss: 0.6861 - val_accuracy: 0.6400
# Epoch 4/100
# 168/168 [==============================] - ETA: 0s - loss: 0.7597 - accuracy: 0.6291
# Epoch 4: val_loss improved from 0.68607 to 0.61593, saving model to ./model_weights/finalyearproject_antispoofing_model_04-0.675789.h5
# 168/168 [==============================] - 37s 221ms/step - loss: 0.7597 - accuracy: 0.6291 - val_loss: 0.6159 - val_accuracy: 0.6758
# Epoch 5/100
# 168/168 [==============================] - ETA: 0s - loss: 0.7099 - accuracy: 0.6434
# Epoch 5: val_loss improved from 0.61593 to 0.56188, saving model to ./model_weights/finalyearproject_antispoofing_model_05-0.715789.h5
# 168/168 [==============================] - 36s 217ms/step - loss: 0.7099 - accuracy: 0.6434 - val_loss: 0.5619 - val_accuracy: 0.7158
# Epoch 6/100
# 168/168 [==============================] - ETA: 0s - loss: 0.6388 - accuracy: 0.6899
# Epoch 6: val_loss improved from 0.56188 to 0.52360, saving model to ./model_weights/finalyearproject_antispoofing_model_06-0.749474.h5
# 168/168 [==============================] - 35s 208ms/step - loss: 0.6388 - accuracy: 0.6899 - val_loss: 0.5236 - val_accuracy: 0.7495
# Epoch 7/100
# 168/168 [==============================] - ETA: 0s - loss: 0.6227 - accuracy: 0.6975
# Epoch 7: val_loss improved from 0.52360 to 0.50577, saving model to ./model_weights/finalyearproject_antispoofing_model_07-0.757895.h5
# 168/168 [==============================] - 35s 207ms/step - loss: 0.6227 - accuracy: 0.6975 - val_loss: 0.5058 - val_accuracy: 0.7579
# Epoch 8/100
# 168/168 [==============================] - ETA: 0s - loss: 0.5883 - accuracy: 0.7142
# Epoch 8: val_loss improved from 0.50577 to 0.45611, saving model to ./model_weights/finalyearproject_antispoofing_model_08-0.795789.h5
# 168/168 [==============================] - 35s 209ms/step - loss: 0.5883 - accuracy: 0.7142 - val_loss: 0.4561 - val_accuracy: 0.7958
# Epoch 9/100
# 168/168 [==============================] - ETA: 0s - loss: 0.5549 - accuracy: 0.7349
# Epoch 9: val_loss improved from 0.45611 to 0.43858, saving model to ./model_weights/finalyearproject_antispoofing_model_09-0.811579.h5
# 168/168 [==============================] - 34s 200ms/step - loss: 0.5549 - accuracy: 0.7349 - val_loss: 0.4386 - val_accuracy: 0.8116
# Epoch 10/100
# 168/168 [==============================] - ETA: 0s - loss: 0.5317 - accuracy: 0.7492
# Epoch 10: val_loss improved from 0.43858 to 0.41553, saving model to ./model_weights/finalyearproject_antispoofing_model_10-0.825263.h5
# 168/168 [==============================] - 35s 206ms/step - loss: 0.5317 - accuracy: 0.7492 - val_loss: 0.4155 - val_accuracy: 0.8253
# Epoch 11/100
# 168/168 [==============================] - ETA: 0s - loss: 0.5027 - accuracy: 0.7740
# Epoch 11: val_loss improved from 0.41553 to 0.39028, saving model to ./model_weights/finalyearproject_antispoofing_model_11-0.838947.h5
# 168/168 [==============================] - 35s 210ms/step - loss: 0.5027 - accuracy: 0.7740 - val_loss: 0.3903 - val_accuracy: 0.8389
# Epoch 12/100
# 168/168 [==============================] - ETA: 0s - loss: 0.4679 - accuracy: 0.7828
# Epoch 12: val_loss improved from 0.39028 to 0.36997, saving model to ./model_weights/finalyearproject_antispoofing_model_12-0.845263.h5
# 168/168 [==============================] - 33s 199ms/step - loss: 0.4679 - accuracy: 0.7828 - val_loss: 0.3700 - val_accuracy: 0.8453
# Epoch 13/100
# 168/168 [==============================] - ETA: 0s - loss: 0.4446 - accuracy: 0.8036
# Epoch 13: val_loss improved from 0.36997 to 0.35278, saving model to ./model_weights/finalyearproject_antispoofing_model_13-0.852632.h5
# 168/168 [==============================] - 35s 209ms/step - loss: 0.4446 - accuracy: 0.8036 - val_loss: 0.3528 - val_accuracy: 0.8526
# Epoch 14/100
# 168/168 [==============================] - ETA: 0s - loss: 0.4444 - accuracy: 0.7979
# Epoch 14: val_loss improved from 0.35278 to 0.33442, saving model to ./model_weights/finalyearproject_antispoofing_model_14-0.861053.h5
# 168/168 [==============================] - 35s 207ms/step - loss: 0.4444 - accuracy: 0.7979 - val_loss: 0.3344 - val_accuracy: 0.8611
# Epoch 15/100
# 168/168 [==============================] - ETA: 0s - loss: 0.4273 - accuracy: 0.8100
# Epoch 15: val_loss improved from 0.33442 to 0.32103, saving model to ./model_weights/finalyearproject_antispoofing_model_15-0.869474.h5
# 168/168 [==============================] - 33s 199ms/step - loss: 0.4273 - accuracy: 0.8100 - val_loss: 0.3210 - val_accuracy: 0.8695
# Epoch 16/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3853 - accuracy: 0.8324
# Epoch 16: val_loss improved from 0.32103 to 0.31194, saving model to ./model_weights/finalyearproject_antispoofing_model_16-0.871579.h5
# 168/168 [==============================] - 36s 216ms/step - loss: 0.3853 - accuracy: 0.8324 - val_loss: 0.3119 - val_accuracy: 0.8716
# Epoch 17/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3892 - accuracy: 0.8362
# Epoch 17: val_loss improved from 0.31194 to 0.30397, saving model to ./model_weights/finalyearproject_antispoofing_model_17-0.876842.h5
# 168/168 [==============================] - 35s 211ms/step - loss: 0.3892 - accuracy: 0.8362 - val_loss: 0.3040 - val_accuracy: 0.8768
# Epoch 18/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3908 - accuracy: 0.8308
# Epoch 18: val_loss improved from 0.30397 to 0.28964, saving model to ./model_weights/finalyearproject_antispoofing_model_18-0.880000.h5
# 168/168 [==============================] - 34s 201ms/step - loss: 0.3908 - accuracy: 0.8308 - val_loss: 0.2896 - val_accuracy: 0.8800
# Epoch 19/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3596 - accuracy: 0.8415
# Epoch 19: val_loss improved from 0.28964 to 0.28100, saving model to ./model_weights/finalyearproject_antispoofing_model_19-0.884211.h5
# 168/168 [==============================] - 35s 210ms/step - loss: 0.3596 - accuracy: 0.8415 - val_loss: 0.2810 - val_accuracy: 0.8842
# Epoch 20/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3448 - accuracy: 0.8584
# Epoch 20: val_loss improved from 0.28100 to 0.27053, saving model to ./model_weights/finalyearproject_antispoofing_model_20-0.887368.h5
# 168/168 [==============================] - 37s 223ms/step - loss: 0.3448 - accuracy: 0.8584 - val_loss: 0.2705 - val_accuracy: 0.8874
# Epoch 21/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.8484
# Epoch 21: val_loss improved from 0.27053 to 0.25934, saving model to ./model_weights/finalyearproject_antispoofing_model_21-0.889474.h5
# 168/168 [==============================] - 34s 201ms/step - loss: 0.3464 - accuracy: 0.8484 - val_loss: 0.2593 - val_accuracy: 0.8895
# Epoch 22/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3329 - accuracy: 0.8629
# Epoch 22: val_loss did not improve from 0.25934
# 168/168 [==============================] - 34s 205ms/step - loss: 0.3329 - accuracy: 0.8629 - val_loss: 0.2724 - val_accuracy: 0.8853
# Epoch 23/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3112 - accuracy: 0.8744
# Epoch 23: val_loss improved from 0.25934 to 0.24306, saving model to ./model_weights/finalyearproject_antispoofing_model_23-0.898947.h5
# 168/168 [==============================] - 35s 208ms/step - loss: 0.3112 - accuracy: 0.8744 - val_loss: 0.2431 - val_accuracy: 0.8989
# Epoch 24/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3167 - accuracy: 0.8689
# Epoch 24: val_loss did not improve from 0.24306
# 168/168 [==============================] - 35s 206ms/step - loss: 0.3167 - accuracy: 0.8689 - val_loss: 0.2443 - val_accuracy: 0.8958
# Epoch 25/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3043 - accuracy: 0.8756
# Epoch 25: val_loss improved from 0.24306 to 0.23089, saving model to ./model_weights/finalyearproject_antispoofing_model_25-0.901053.h5
# 168/168 [==============================] - 35s 210ms/step - loss: 0.3043 - accuracy: 0.8756 - val_loss: 0.2309 - val_accuracy: 0.9011
# Epoch 26/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.8808
# Epoch 26: val_loss did not improve from 0.23089
# 168/168 [==============================] - 33s 196ms/step - loss: 0.3022 - accuracy: 0.8808 - val_loss: 0.2366 - val_accuracy: 0.8958
# Epoch 27/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2850 - accuracy: 0.8813
# Epoch 27: val_loss improved from 0.23089 to 0.23062, saving model to ./model_weights/finalyearproject_antispoofing_model_27-0.898947.h5
# 168/168 [==============================] - 35s 208ms/step - loss: 0.2850 - accuracy: 0.8813 - val_loss: 0.2306 - val_accuracy: 0.8989
# Epoch 28/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2807 - accuracy: 0.8851
# Epoch 28: val_loss improved from 0.23062 to 0.22637, saving model to ./model_weights/finalyearproject_antispoofing_model_28-0.901053.h5
# 168/168 [==============================] - 34s 205ms/step - loss: 0.2807 - accuracy: 0.8851 - val_loss: 0.2264 - val_accuracy: 0.9011
# Epoch 29/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2742 - accuracy: 0.8863
# Epoch 29: val_loss improved from 0.22637 to 0.21066, saving model to ./model_weights/finalyearproject_antispoofing_model_29-0.907368.h5
# 168/168 [==============================] - 34s 205ms/step - loss: 0.2742 - accuracy: 0.8863 - val_loss: 0.2107 - val_accuracy: 0.9074
# Epoch 30/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.8896
# Epoch 30: val_loss improved from 0.21066 to 0.20743, saving model to ./model_weights/finalyearproject_antispoofing_model_30-0.907368.h5
# 168/168 [==============================] - 35s 211ms/step - loss: 0.2762 - accuracy: 0.8896 - val_loss: 0.2074 - val_accuracy: 0.9074
# Epoch 31/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2837 - accuracy: 0.8813
# Epoch 31: val_loss improved from 0.20743 to 0.20114, saving model to ./model_weights/finalyearproject_antispoofing_model_31-0.911579.h5
# 168/168 [==============================] - 35s 206ms/step - loss: 0.2837 - accuracy: 0.8813 - val_loss: 0.2011 - val_accuracy: 0.9116
# Epoch 32/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.9001
# Epoch 32: val_loss did not improve from 0.20114
# 168/168 [==============================] - 34s 203ms/step - loss: 0.2484 - accuracy: 0.9001 - val_loss: 0.2021 - val_accuracy: 0.9084
# Epoch 33/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 0.9025
# Epoch 33: val_loss improved from 0.20114 to 0.19468, saving model to ./model_weights/finalyearproject_antispoofing_model_33-0.912632.h5
# 168/168 [==============================] - 33s 198ms/step - loss: 0.2485 - accuracy: 0.9025 - val_loss: 0.1947 - val_accuracy: 0.9126
# Epoch 34/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2487 - accuracy: 0.8954
# Epoch 34: val_loss did not improve from 0.19468
# 168/168 [==============================] - 34s 201ms/step - loss: 0.2487 - accuracy: 0.8954 - val_loss: 0.2015 - val_accuracy: 0.9095
# Epoch 35/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2486 - accuracy: 0.8968
# Epoch 35: val_loss improved from 0.19468 to 0.18781, saving model to ./model_weights/finalyearproject_antispoofing_model_35-0.917895.h5
# 168/168 [==============================] - 34s 205ms/step - loss: 0.2486 - accuracy: 0.8968 - val_loss: 0.1878 - val_accuracy: 0.9179
# Epoch 36/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.8956
# Epoch 36: val_loss did not improve from 0.18781
# 168/168 [==============================] - 34s 202ms/step - loss: 0.2614 - accuracy: 0.8956 - val_loss: 0.1902 - val_accuracy: 0.9137
# Epoch 37/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.9037
# Epoch 37: val_loss improved from 0.18781 to 0.17933, saving model to ./model_weights/finalyearproject_antispoofing_model_37-0.924211.h5
# 168/168 [==============================] - 34s 205ms/step - loss: 0.2392 - accuracy: 0.9037 - val_loss: 0.1793 - val_accuracy: 0.9242
# Epoch 38/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2249 - accuracy: 0.9077
# Epoch 38: val_loss did not improve from 0.17933
# 168/168 [==============================] - 35s 206ms/step - loss: 0.2249 - accuracy: 0.9077 - val_loss: 0.1851 - val_accuracy: 0.9158
# Epoch 39/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2245 - accuracy: 0.9120
# Epoch 39: val_loss improved from 0.17933 to 0.17752, saving model to ./model_weights/finalyearproject_antispoofing_model_39-0.920000.h5
# 168/168 [==============================] - 33s 198ms/step - loss: 0.2245 - accuracy: 0.9120 - val_loss: 0.1775 - val_accuracy: 0.9200
# Epoch 40/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2059 - accuracy: 0.9192
# Epoch 40: val_loss did not improve from 0.17752
# 168/168 [==============================] - 36s 217ms/step - loss: 0.2059 - accuracy: 0.9192 - val_loss: 0.1808 - val_accuracy: 0.9211
# Epoch 41/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2160 - accuracy: 0.9187
# Epoch 41: val_loss improved from 0.17752 to 0.16605, saving model to ./model_weights/finalyearproject_antispoofing_model_41-0.927368.h5
# 168/168 [==============================] - 35s 205ms/step - loss: 0.2160 - accuracy: 0.9187 - val_loss: 0.1660 - val_accuracy: 0.9274
# Epoch 42/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2223 - accuracy: 0.9104
# Epoch 42: val_loss did not improve from 0.16605
# 168/168 [==============================] - 34s 204ms/step - loss: 0.2223 - accuracy: 0.9104 - val_loss: 0.1672 - val_accuracy: 0.9274
# Epoch 43/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9154
# Epoch 43: val_loss improved from 0.16605 to 0.16300, saving model to ./model_weights/finalyearproject_antispoofing_model_43-0.928421.h5
# 168/168 [==============================] - 33s 197ms/step - loss: 0.2058 - accuracy: 0.9154 - val_loss: 0.1630 - val_accuracy: 0.9284
# Epoch 44/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.9144
# Epoch 44: val_loss did not improve from 0.16300
# 168/168 [==============================] - 34s 202ms/step - loss: 0.2088 - accuracy: 0.9144 - val_loss: 0.1659 - val_accuracy: 0.9274
# Epoch 45/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1999 - accuracy: 0.9225
# Epoch 45: val_loss improved from 0.16300 to 0.15660, saving model to ./model_weights/finalyearproject_antispoofing_model_45-0.932632.h5
# 168/168 [==============================] - 34s 204ms/step - loss: 0.1999 - accuracy: 0.9225 - val_loss: 0.1566 - val_accuracy: 0.9326
# Epoch 46/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1978 - accuracy: 0.9204
# Epoch 46: val_loss improved from 0.15660 to 0.15360, saving model to ./model_weights/finalyearproject_antispoofing_model_46-0.933684.h5
# 168/168 [==============================] - 36s 212ms/step - loss: 0.1978 - accuracy: 0.9204 - val_loss: 0.1536 - val_accuracy: 0.9337
# Epoch 47/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9218
# Epoch 47: val_loss improved from 0.15360 to 0.14117, saving model to ./model_weights/finalyearproject_antispoofing_model_47-0.947368.h5
# 168/168 [==============================] - 33s 196ms/step - loss: 0.1980 - accuracy: 0.9218 - val_loss: 0.1412 - val_accuracy: 0.9474
# Epoch 48/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2057 - accuracy: 0.9187
# Epoch 48: val_loss did not improve from 0.14117
# 168/168 [==============================] - 34s 202ms/step - loss: 0.2057 - accuracy: 0.9187 - val_loss: 0.1446 - val_accuracy: 0.9421
# Epoch 49/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1942 - accuracy: 0.9271
# Epoch 49: val_loss did not improve from 0.14117
# 168/168 [==============================] - 34s 204ms/step - loss: 0.1942 - accuracy: 0.9271 - val_loss: 0.1458 - val_accuracy: 0.9400
# Epoch 50/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9192
# Epoch 50: val_loss improved from 0.14117 to 0.14046, saving model to ./model_weights/finalyearproject_antispoofing_model_50-0.946316.h5
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1994 - accuracy: 0.9192 - val_loss: 0.1405 - val_accuracy: 0.9463
# Epoch 51/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1966 - accuracy: 0.9244
# Epoch 51: val_loss improved from 0.14046 to 0.13295, saving model to ./model_weights/finalyearproject_antispoofing_model_51-0.951579.h5
# 168/168 [==============================] - 35s 208ms/step - loss: 0.1966 - accuracy: 0.9244 - val_loss: 0.1329 - val_accuracy: 0.9516
# Epoch 52/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9240
# Epoch 52: val_loss improved from 0.13295 to 0.12997, saving model to ./model_weights/finalyearproject_antispoofing_model_52-0.950526.h5
# 168/168 [==============================] - 33s 197ms/step - loss: 0.1979 - accuracy: 0.9240 - val_loss: 0.1300 - val_accuracy: 0.9505
# Epoch 53/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1782 - accuracy: 0.9349
# Epoch 53: val_loss improved from 0.12997 to 0.12503, saving model to ./model_weights/finalyearproject_antispoofing_model_53-0.952632.h5
# 168/168 [==============================] - 35s 207ms/step - loss: 0.1782 - accuracy: 0.9349 - val_loss: 0.1250 - val_accuracy: 0.9526
# Epoch 54/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1866 - accuracy: 0.9249
# Epoch 54: val_loss did not improve from 0.12503
# 168/168 [==============================] - 34s 204ms/step - loss: 0.1866 - accuracy: 0.9249 - val_loss: 0.1314 - val_accuracy: 0.9495
# Epoch 55/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1755 - accuracy: 0.9313
# Epoch 55: val_loss did not improve from 0.12503
# 168/168 [==============================] - 35s 207ms/step - loss: 0.1755 - accuracy: 0.9313 - val_loss: 0.1289 - val_accuracy: 0.9495
# Epoch 56/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1788 - accuracy: 0.9318
# Epoch 56: val_loss improved from 0.12503 to 0.12460, saving model to ./model_weights/finalyearproject_antispoofing_model_56-0.949474.h5
# 168/168 [==============================] - 35s 207ms/step - loss: 0.1788 - accuracy: 0.9318 - val_loss: 0.1246 - val_accuracy: 0.9495
# Epoch 57/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.9316
# Epoch 57: val_loss improved from 0.12460 to 0.12137, saving model to ./model_weights/finalyearproject_antispoofing_model_57-0.950526.h5
# 168/168 [==============================] - 35s 208ms/step - loss: 0.1703 - accuracy: 0.9316 - val_loss: 0.1214 - val_accuracy: 0.9505
# Epoch 58/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1788 - accuracy: 0.9290
# Epoch 58: val_loss improved from 0.12137 to 0.11502, saving model to ./model_weights/finalyearproject_antispoofing_model_58-0.955789.h5
# 168/168 [==============================] - 33s 196ms/step - loss: 0.1788 - accuracy: 0.9290 - val_loss: 0.1150 - val_accuracy: 0.9558
# Epoch 59/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9304
# Epoch 59: val_loss did not improve from 0.11502
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1658 - accuracy: 0.9304 - val_loss: 0.1179 - val_accuracy: 0.9526
# Epoch 60/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1800 - accuracy: 0.9311
# Epoch 60: val_loss did not improve from 0.11502
# 168/168 [==============================] - 33s 194ms/step - loss: 0.1800 - accuracy: 0.9311 - val_loss: 0.1186 - val_accuracy: 0.9516
# Epoch 61/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9352
# Epoch 61: val_loss did not improve from 0.11502
# 168/168 [==============================] - 34s 202ms/step - loss: 0.1643 - accuracy: 0.9352 - val_loss: 0.1239 - val_accuracy: 0.9484
# Epoch 62/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1838 - accuracy: 0.9328
# Epoch 62: val_loss improved from 0.11502 to 0.11321, saving model to ./model_weights/finalyearproject_antispoofing_model_62-0.954737.h5
# 168/168 [==============================] - 35s 207ms/step - loss: 0.1838 - accuracy: 0.9328 - val_loss: 0.1132 - val_accuracy: 0.9547
# Epoch 63/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1656 - accuracy: 0.9361
# Epoch 63: val_loss did not improve from 0.11321
# 168/168 [==============================] - 33s 194ms/step - loss: 0.1656 - accuracy: 0.9361 - val_loss: 0.1150 - val_accuracy: 0.9537
# Epoch 64/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9409
# Epoch 64: val_loss did not improve from 0.11321
# 168/168 [==============================] - 34s 202ms/step - loss: 0.1517 - accuracy: 0.9409 - val_loss: 0.1163 - val_accuracy: 0.9505
# Epoch 65/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9414
# Epoch 65: val_loss improved from 0.11321 to 0.10267, saving model to ./model_weights/finalyearproject_antispoofing_model_65-0.958947.h5
# 168/168 [==============================] - 36s 212ms/step - loss: 0.1503 - accuracy: 0.9414 - val_loss: 0.1027 - val_accuracy: 0.9589
# Epoch 66/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.9402
# Epoch 66: val_loss improved from 0.10267 to 0.10215, saving model to ./model_weights/finalyearproject_antispoofing_model_66-0.958947.h5
# 168/168 [==============================] - 34s 205ms/step - loss: 0.1661 - accuracy: 0.9402 - val_loss: 0.1022 - val_accuracy: 0.9589
# Epoch 67/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1583 - accuracy: 0.9380
# Epoch 67: val_loss did not improve from 0.10215
# 168/168 [==============================] - 34s 200ms/step - loss: 0.1583 - accuracy: 0.9380 - val_loss: 0.1044 - val_accuracy: 0.9568
# Epoch 68/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9435
# Epoch 68: val_loss improved from 0.10215 to 0.09756, saving model to ./model_weights/finalyearproject_antispoofing_model_68-0.958947.h5
# 168/168 [==============================] - 34s 204ms/step - loss: 0.1475 - accuracy: 0.9435 - val_loss: 0.0976 - val_accuracy: 0.9589
# Epoch 69/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1604 - accuracy: 0.9433
# Epoch 69: val_loss did not improve from 0.09756
# 168/168 [==============================] - 34s 203ms/step - loss: 0.1604 - accuracy: 0.9433 - val_loss: 0.1024 - val_accuracy: 0.9558
# Epoch 70/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9399
# Epoch 70: val_loss improved from 0.09756 to 0.09538, saving model to ./model_weights/finalyearproject_antispoofing_model_70-0.960000.h5
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1525 - accuracy: 0.9399 - val_loss: 0.0954 - val_accuracy: 0.9600
# Epoch 71/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1526 - accuracy: 0.9387
# Epoch 71: val_loss did not improve from 0.09538
# 168/168 [==============================] - 33s 196ms/step - loss: 0.1526 - accuracy: 0.9387 - val_loss: 0.1000 - val_accuracy: 0.9558
# Epoch 72/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9416
# Epoch 72: val_loss did not improve from 0.09538
# 168/168 [==============================] - 34s 204ms/step - loss: 0.1528 - accuracy: 0.9416 - val_loss: 0.0960 - val_accuracy: 0.9589
# Epoch 73/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9445
# Epoch 73: val_loss improved from 0.09538 to 0.09391, saving model to ./model_weights/finalyearproject_antispoofing_model_73-0.958947.h5
# 168/168 [==============================] - 35s 207ms/step - loss: 0.1402 - accuracy: 0.9445 - val_loss: 0.0939 - val_accuracy: 0.9589
# Epoch 74/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9440
# Epoch 74: val_loss improved from 0.09391 to 0.08693, saving model to ./model_weights/finalyearproject_antispoofing_model_74-0.963158.h5
# 168/168 [==============================] - 35s 208ms/step - loss: 0.1475 - accuracy: 0.9440 - val_loss: 0.0869 - val_accuracy: 0.9632
# Epoch 75/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1512 - accuracy: 0.9421
# Epoch 75: val_loss improved from 0.08693 to 0.08262, saving model to ./model_weights/finalyearproject_antispoofing_model_75-0.966316.h5
# 168/168 [==============================] - 33s 197ms/step - loss: 0.1512 - accuracy: 0.9421 - val_loss: 0.0826 - val_accuracy: 0.9663
# Epoch 76/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9440
# Epoch 76: val_loss did not improve from 0.08262
# 168/168 [==============================] - 35s 207ms/step - loss: 0.1401 - accuracy: 0.9440 - val_loss: 0.1019 - val_accuracy: 0.9516
# Epoch 77/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9447
# Epoch 77: val_loss did not improve from 0.08262
# 168/168 [==============================] - 34s 202ms/step - loss: 0.1453 - accuracy: 0.9447 - val_loss: 0.0940 - val_accuracy: 0.9558
# Epoch 78/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9464
# Epoch 78: val_loss did not improve from 0.08262
# 168/168 [==============================] - 34s 202ms/step - loss: 0.1400 - accuracy: 0.9464 - val_loss: 0.0922 - val_accuracy: 0.9579
# Epoch 79/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9426
# Epoch 79: val_loss did not improve from 0.08262
# 168/168 [==============================] - 33s 196ms/step - loss: 0.1432 - accuracy: 0.9426 - val_loss: 0.0890 - val_accuracy: 0.9600
# Epoch 80/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.9530
# Epoch 80: val_loss did not improve from 0.08262
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1287 - accuracy: 0.9530 - val_loss: 0.0870 - val_accuracy: 0.9600
# Epoch 81/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9471
# Epoch 81: val_loss did not improve from 0.08262
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1421 - accuracy: 0.9471 - val_loss: 0.0835 - val_accuracy: 0.9653
# Epoch 82/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9461
# Epoch 82: val_loss did not improve from 0.08262
# 168/168 [==============================] - 34s 203ms/step - loss: 0.1443 - accuracy: 0.9461 - val_loss: 0.0917 - val_accuracy: 0.9568
# Epoch 83/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9404
# Epoch 83: val_loss did not improve from 0.08262
# 168/168 [==============================] - 34s 205ms/step - loss: 0.1490 - accuracy: 0.9404 - val_loss: 0.0904 - val_accuracy: 0.9579
# Epoch 84/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1459 - accuracy: 0.9456
# Epoch 84: val_loss improved from 0.08262 to 0.08250, saving model to ./model_weights/finalyearproject_antispoofing_model_84-0.963158.h5
# 168/168 [==============================] - 34s 205ms/step - loss: 0.1459 - accuracy: 0.9456 - val_loss: 0.0825 - val_accuracy: 0.9632
# Epoch 85/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9504
# Epoch 85: val_loss improved from 0.08250 to 0.07987, saving model to ./model_weights/finalyearproject_antispoofing_model_85-0.965263.h5
# 168/168 [==============================] - 34s 205ms/step - loss: 0.1290 - accuracy: 0.9504 - val_loss: 0.0799 - val_accuracy: 0.9653
# Epoch 86/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1353 - accuracy: 0.9516
# Epoch 86: val_loss did not improve from 0.07987
# 168/168 [==============================] - 33s 197ms/step - loss: 0.1353 - accuracy: 0.9516 - val_loss: 0.0799 - val_accuracy: 0.9653
# Epoch 87/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1337 - accuracy: 0.9454
# Epoch 87: val_loss improved from 0.07987 to 0.07907, saving model to ./model_weights/finalyearproject_antispoofing_model_87-0.965263.h5
# 168/168 [==============================] - 34s 205ms/step - loss: 0.1337 - accuracy: 0.9454 - val_loss: 0.0791 - val_accuracy: 0.9653
# Epoch 88/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1368 - accuracy: 0.9492
# Epoch 88: val_loss did not improve from 0.07907
# 168/168 [==============================] - 35s 209ms/step - loss: 0.1368 - accuracy: 0.9492 - val_loss: 0.0825 - val_accuracy: 0.9611
# Epoch 89/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9456
# Epoch 89: val_loss did not improve from 0.07907
# 168/168 [==============================] - 34s 204ms/step - loss: 0.1356 - accuracy: 0.9456 - val_loss: 0.0825 - val_accuracy: 0.9611
# Epoch 90/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1308 - accuracy: 0.9499
# Epoch 90: val_loss improved from 0.07907 to 0.07123, saving model to ./model_weights/finalyearproject_antispoofing_model_90-0.969474.h5
# 168/168 [==============================] - 36s 212ms/step - loss: 0.1308 - accuracy: 0.9499 - val_loss: 0.0712 - val_accuracy: 0.9695
# Epoch 91/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9485
# Epoch 91: val_loss improved from 0.07123 to 0.06923, saving model to ./model_weights/finalyearproject_antispoofing_model_91-0.972632.h5
# 168/168 [==============================] - 33s 198ms/step - loss: 0.1342 - accuracy: 0.9485 - val_loss: 0.0692 - val_accuracy: 0.9726
# Epoch 92/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1333 - accuracy: 0.9473
# Epoch 92: val_loss did not improve from 0.06923
# 168/168 [==============================] - 35s 211ms/step - loss: 0.1333 - accuracy: 0.9473 - val_loss: 0.0743 - val_accuracy: 0.9663
# Epoch 93/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9518
# Epoch 93: val_loss did not improve from 0.06923
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1241 - accuracy: 0.9518 - val_loss: 0.0750 - val_accuracy: 0.9653
# Epoch 94/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9538
# Epoch 94: val_loss did not improve from 0.06923
# 168/168 [==============================] - 33s 196ms/step - loss: 0.1208 - accuracy: 0.9538 - val_loss: 0.0744 - val_accuracy: 0.9663
# Epoch 95/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9476
# Epoch 95: val_loss did not improve from 0.06923
# 168/168 [==============================] - 34s 204ms/step - loss: 0.1284 - accuracy: 0.9476 - val_loss: 0.0756 - val_accuracy: 0.9674
# Epoch 96/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.9507
# Epoch 96: val_loss did not improve from 0.06923
# 168/168 [==============================] - 34s 204ms/step - loss: 0.1286 - accuracy: 0.9507 - val_loss: 0.0777 - val_accuracy: 0.9632
# Epoch 97/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9540
# Epoch 97: val_loss improved from 0.06923 to 0.06818, saving model to ./model_weights/finalyearproject_antispoofing_model_97-0.969474.h5
# 168/168 [==============================] - 34s 205ms/step - loss: 0.1167 - accuracy: 0.9540 - val_loss: 0.0682 - val_accuracy: 0.9695
# Epoch 98/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1113 - accuracy: 0.9576
# Epoch 98: val_loss improved from 0.06818 to 0.06679, saving model to ./model_weights/finalyearproject_antispoofing_model_98-0.970526.h5
# 168/168 [==============================] - 33s 198ms/step - loss: 0.1113 - accuracy: 0.9576 - val_loss: 0.0668 - val_accuracy: 0.9705
# Epoch 99/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9538
# Epoch 99: val_loss did not improve from 0.06679
# 168/168 [==============================] - 36s 211ms/step - loss: 0.1198 - accuracy: 0.9538 - val_loss: 0.0694 - val_accuracy: 0.9695
# Epoch 100/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9516
# Epoch 100: val_loss did not improve from 0.06679
# 168/168 [==============================] - 34s 203ms/step - loss: 0.1295 - accuracy: 0.9516 - val_loss: 0.0669 - val_accuracy: 0.9716

# %%
# serialize model to JSON
model_json = model.to_json()
with open("finalyearproject_antispoofing_model_mobilenet.json", "w") as json_file:
    json_file.write(model_json)

# %%
import matplotlib.pyplot as plt
train_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
epochs = range(1,101)
plt.plot(epochs,train_accuracy,'g',label='Training Accuracy')
plt.plot(epochs,validation_accuracy,'b',label='Validation Accuracy')
plt.title('Training Vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,101)
plt.plot(epochs,train_loss,'g', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from keras.preprocessing import image
import numpy as np
def check_fakes(path,category_type):
  predictor = {}
  path= os.path.join(path,category_type)
  for img in os.listdir(path):
    try:
      img = image.load_img(os.path.join(path,img),target_size=(160,160))
      img = image.img_to_array(img)
      img = np.expand_dims(img,axis=0)
      img = img / 255.0
      prediction = model.predict(img)
      if prediction > 0.5:
        prediction_class = 1
      else:
        prediction_class = 0
      result = categories[prediction_class]
      if result not in predictor:
        predictor[result] = 1
      else:
        predictor[result] += 1
    except Exception as e:
      pass
  return predictor

# %%
check_fakes(test_dir,categories[1])
# Out:
# {'real': 19, 'spoof': 455}

# %%
check_fakes(test_dir,categories[0])
# Out:
# {'real': 471, 'spoof': 6}

# %%
(19+6)/(19+455+471+6)*100
# Out:
# 2.6288117770767614

# %%
100-2.6288
# Out:
# 97.3712
